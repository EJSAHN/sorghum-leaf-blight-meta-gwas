# %% [markdown]
# # Run sorghum leaf blight dual-trait meta-GWAS pipeline
#
# This clean notebook runs the Excel-only public pipeline. It does not generate figures.

# %%
from pathlib import Path
import sys

repo_root = Path.cwd().parent
sys.path.insert(0, str(repo_root / 'src'))

from sorghum_leaf_blight_meta_gwas import PipelineConfig, run_pipeline

cfg = PipelineConfig(base_dir=str(repo_root / 'data'))
# Put input files in repo_root / 'data' or change base_dir below.
output = run_pipeline(cfg)
print(output)
